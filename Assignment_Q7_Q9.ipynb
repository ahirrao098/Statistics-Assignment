# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Q7.Calculate Mean, Median, Mode, Variance, Standard Deviation, Range &     comment about the values / draw inferences, for the given dataset
# -	For Points,Score,Weigh>
# Find Mean, Median, Mode, Variance, Standard Deviation, and Range and also Comment about the values/ Draw some inferences.

# %%
Q7=pd.read_csv('Q7.csv')

# %%
Q7
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
Q7.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
#for points Mean, Median, Mode, Variance, Standard Deviation, and Range
#points

# %%
print("mean is",round(Q7.Points.mean(),4))
# Out:
# mean is 3.5966

# %%
print("mode is",round(Q7.Points.mode(),4))
# Out:
# mode is 0    3.07
# 1    3.92
# dtype: float64

# %%
print("median is",round(Q7.Points.median(),4))
# Out:
# median is 3.695

# %%
print("std is",round(Q7.Points.std(),4))
# Out:
# std is 0.5347

# %%
print("range is",round(Q7.Points.max()-Q7.Points.min(),4))
# Out:
# range is 2.17

# %%
#Sccore
print("mean is",round(Q7.Score.mean(),4))
print("mode is",round(Q7.Score.mode(),4))
print("median is",round(Q7.Score.median(),4))
print("std is",round(Q7.Score.std(),4))
print("range is",round(Q7.Score.max()-Q7.Points.min(),4))
# Out:
# mean is 3.2172
# mode is 0    3.44
# dtype: float64
# median is 3.325
# std is 0.9785
# range is 2.664

# %%
#Weight
print("mean is",round(Q7.Weigh.mean(),4))
print("mode is",round(Q7.Weigh.mode(),4))
print("median is",round(Q7.Weigh.median(),4))
print("std is",round(Q7.Weigh.std(),4))
print("range is",round(Q7.Weigh.max()-Q7.Points.min(),4))
# Out:
# mean is 17.8488
# mode is 0    17.02
# 1    18.90
# dtype: float64
# median is 17.71
# std is 1.7869
# range is 20.14

# %%
Q7.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %% [markdown]
# Q9) Calculate Skewness, Kurtosis & draw inferences on the following data
#       Cars speed and distance

# %%
Q9=pd.read_csv('Q9_a.csv')

# %%
Q9
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
Q9.skew()#skewness
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
Q9.kurt()#kurtosis
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
Speed=Q9[['speed']]
Speed
# Out:
#     speed
# 0       4
# 1       4
# 2       7
# 3       7
# 4       8
# 5       9
# 6      10
# 7      10
# 8      10
# 9      11
# 10     11
# 11     12
# 12     12
# 13     12
# 14     12
# 15     13
# 16     13
# 17     13
# 18     13
# 19     14
# 20     14
# 21     14
# 22     14
# 23     15
# 24     15
# 25     15
# 26     16
# 27     16
# 28     17
# 29     17
# 30     17
# 31     18
# 32     18
# 33     18
# 34     18
# 35     19
# 36     19
# 37     19
# 38     20
# 39     20
# 40     20
# 41     20
# 42     20
# 43     22
# 44     23
# 45     24
# 46     24
# 47     24
# 48     24
# 49     25

# %%
Speed.skew()#skewness
# Out:
# speed   -0.11751
# dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(Q9.speed,label='Speed')#distribution plot
#plt.xlabel('gain')
#plt.ylabel('density')

#plt.legend()

# %%
sns.distplot(Q9.dist,label='dist')#distribution plot

# %% [markdown]
# SP and Weight(WT)

# %%
Q9=pd.read_csv('Q9_b.csv')

# %%
Q9
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
Q9.skew()#skewness
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
Q9.kurt()#kurtosis
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
sns.distplot(Q9.SP)

# %%
sns.distplot(Q9.WT)
